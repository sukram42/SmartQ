# %%
datapath = "queuedatabase.db"
import sqlite3
import pandas as pd
# Create your connection.
cnx = sqlite3.connect(datapath)
pd.read_sql_query("SELECT * FROM sqlite_master", cnx)["name"]
# pd.read_sql_query("SELECT * FROM simple_app_note",cnx)
# Out:
# 0      shop
# 1    people
# 2      user
# Name: name, dtype: object

# %%
pd.read_sql_query("SELECT * FROM shop",cnx)
# Out:
#     id   name   category                address   latitude  longitude  \
# 0    1  Edeka       food                 Munich  10.000000  10.000000
# 1    2  Edeka       food                 Munich  10.000000  10.000000
# 2    3  Edeka       food                 Munich  10.000000  10.000000
# 3    4  Edeka       food                 Munich  10.000000  10.000000
# 4    5  Edeka       food                 Munich  10.000000  10.000000
# 5    6  Edeka       food                 Munich  10.000000  10.000000
# 6    7  Edeka       food                 Munich  10.000000  10.000000
# 7    8  Edeka       food                 Munich  10.000000  10.000000
# 8    9  Edeka       food                 Munich  48.137108  11.575382
# 9   10   ALDI  groceries                 munich  48.137108  11.575382
# 10  11   REWE  groceries  Tal 13, 80331 München  48.136242  11.579122
# 11  12   Lidl  groceries  Tal 13, 80331 München  48.136242  11.579122
#
#     storespace  maxcapacity
# ...

# %%
from flask import json, jsonify
data = pd.read_sql_query('SELECT * FROM shop',cnx)
jsonify(json_list = data)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-e2e5ce1aae3f> in <module>
#       1 from flask import json, jsonify
#       2 data = pd.read_sql_query('SELECT * FROM shop',cnx)
# ----> 3 jsonify(json_list = data)
#
# c:\python36\lib\site-packages\flask\json\__init__.py in jsonify(*args, **kwargs)
#     356     separators = (",", ":")
#     357
# --> 358     if current_app.config["JSONIFY_PRETTYPRINT_REGULAR"] or current_app.debug:
#     359         indent = 2
#     360         separators = (", ", ": ")
#
# c:\python36\lib\site-packages\werkzeug\local.py in __getattr__(self, name)
#     346         if name == "__members__":
#     347             return dir(self._get_current_object())
# --> 348         return getattr(self._get_current_object(), name)
#     349
#     350     def __setitem__(self, key, value):
#
# ...

# %%
data
# Out:
#    id   name category address   latitude  longitude  storespace  maxcapacity
# 0   1  Edeka     food  Munich  10.000000  10.000000         200           40
# 1   2  Edeka     food  Munich  10.000000  10.000000         200           40
# 2   3  Edeka     food  Munich  10.000000  10.000000         200           40
# 3   4  Edeka     food  Munich  10.000000  10.000000         200           40
# 4   5  Edeka     food  Munich  10.000000  10.000000         200           40
# 5   6  Edeka     food  Munich  10.000000  10.000000         200           40
# 6   7  Edeka     food  Munich  10.000000  10.000000         200           40
# 7   8  Edeka     food  Munich  10.000000  10.000000         200           40
# 8   9  Edeka     food  Munich  48.137108  11.575382         200           40
